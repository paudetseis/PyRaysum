# %%
import numpy as np
from pyraysum import prs

# %%
modfile = '../models/model_Porter2011_dip.txt'

# %%
wvtype = 'P'
npts = 3000
dt = 0.01
slow = 0.06
baz = np.arange(0., 360., 10.)
rot = 1

model = prs.read_model(modfile)

rflist = prs.run_prs(model, slow=slow, npts=npts, dt=dt, baz=baz, wvtype=wvtype, rot=rot, rf=True)

# %%
rflist[5].plot()
